# %%
# mount google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 # necessary basic libraries
import pandas as pd
import numpy as np
import cv2
import random
import matplotlib.pyplot as plt
from PIL import Image
import os
import numpy as np
import json
#import png
import re
import time
import glob

# %%
entries = os.listdir('/content/drive/MyDrive/forestseg/paracou_data/Panayiotis_Outputs/ForTrainingSegmentation/train')
print(entries)

for i in entries:
  if 'geojson' in i:
    filename = '/content/drive/MyDrive/forestseg/paracou_data/Panayiotis_Outputs/ForTrainingSegmentation/train/' + i
    print(i)
    print(filename)
    j=i[:-8]
    print(j)
    k= j + '.png'
    Dict = {"imagePath": k}
    print(Dict)
    with open(filename, "r" ) as f:
      data = json.load(f)
      data.update(Dict)
    with open(filename,"w") as f:
        json.dump(data,f)
# Out:
# ['Paracou_20201105_RGB_5cm_mosa_rect_tile_286400_583762.png', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286400_583762.geojson', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286559_583854.png', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286559_583854.geojson', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286748_583830.png', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286748_583830.geojson', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286716_583929.png', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286716_583929.geojson', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286818_583948.png', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286818_583948.geojson', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_287000_583744.png', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_287000_583744.geojson', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_287153_583851.png', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_287153_583851.geojson', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286952_583994.png', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286952_583994
# ...

# %%
entries = os.listdir('/content/drive/MyDrive/forestseg/paracou_data/Panayiotis_Outputs/ForTrainingSegmentation/test')
print(entries)

for i in entries:
  if 'geojson' in i:
    filename = '/content/drive/MyDrive/forestseg/paracou_data/Panayiotis_Outputs/ForTrainingSegmentation/test/' + i
    print(i)
    print(filename)
    j=i[:-8]
    print(j)
    k= j + '.png'
    Dict = {"imagePath": k}
    print(Dict)
    with open(filename, "r" ) as f:
      data = json.load(f)
      data.update(Dict)
    with open(filename,"w") as f:
        json.dump(data,f)
# Out:
# ['Paracou_20201105_RGB_5cm_mosa_rect_tile_286400_583662.png', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286400_583662.geojson', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_287295_584130.png', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_287295_584130.geojson', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286450_583662.png', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286450_583662.geojson', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_287002_583994.png', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_287002_583994.geojson', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286748_583880.png', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286748_583880.geojson', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286952_584044.png', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286952_584044.geojson', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286798_583880.png', 'Paracou_20201105_RGB_5cm_mosa_rect_tile_286798_583880.geojson', 'Paracou_20210208_RGB_5cm_mosa_rect_tile_286400_583662.png', 'Paracou_20210208_RGB_5cm_mosa_rect_tile_286400_583662
# ...
