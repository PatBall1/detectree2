# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install git+https://github.com/PatBall1/detectree2.git
# Out:
# Mounted at /content/drive
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/PatBall1/detectree2.git to /tmp/pip-req-build-730153x7
#   Running command git clone --filter=blob:none --quiet https://github.com/PatBall1/detectree2.git /tmp/pip-req-build-730153x7
#   Resolved https://github.com/PatBall1/detectree2.git to commit 6d56a8278cde15f8000cd238e0b5484b3d536699
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-install-yqs_4qt1/detectron2_298bffdb510141e4bcee3243d099b21e
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-install-yqs_4qt1/detectron2_298bffdb510141e4bcee3243d099b21e
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 38af375052d3ae7331141bc1a22cfa2713b02987
#   Preparing metadata (setup.py) ... done
# ...

# %%
import shutil
from detectree2.models.train import register_test_data, setup_cfg, predictions_on_data
from detectree2.models.predict import predict_on_data
from detectree2.models.outputs import to_eval_geojson, clean_predictions
from detectron2.engine import DefaultPredictor

#cfg.MODEL.DEVICE='cpu'
dir = "/content/drive/Shareddrives/detectree2/"
# Out:
# /usr/local/lib/python3.8/dist-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/detectree2/models/outputs.py:12: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# ...

# %% [markdown]
# # Set parameters

# %% [markdown]
# ### For Paracou

# %%
# To see resize performance
suffix = "30_30_0.4"
name = "resize_full"
tiles = "/tiles2016_"
date = "221222"
model_num = "2"


#trained_model = "/content/drive/Shareddrives/detectree2/models/220723_withParacouUAV.pth"
trained_model = dir +  "/models/" + date + "_" + name + "/model_" + model_num + ".pth"

site_path = "/content/drive/Shareddrives/detectree2/data/" + "Paracou"
img_path = site_path + "/rgb/2016/Paracou_RGB_2016_10cm.tif"
lidar = "/content/drive/Shareddrives/detectree2/data/Paracou/lidar/Par_2016_CHM_g10_sub0.2_1m.tif"

test_folder = site_path + tiles + suffix + "/test"
pred_folder = test_folder + "/predictions_resize"
shutil.rmtree(site_path + tiles + suffix + "/test/" + "predictions_resize", True)
print(date + "_" + name + "/model_" + model_num + ".pth")
# Out:
# 221222_resize_full/model_2.pth

# %%
suffix = "30_30_0.4"
name = "Paracou2016"
tiles = "/tiles2016_"
date = "221026"
model_num = "32"


#trained_model = "/content/drive/Shareddrives/detectree2/models/220723_withParacouUAV.pth"
#trained_model = dir +  "/models/" + date + "_" + name + "/model_" + model_num + ".pth"

site_path = "/content/drive/Shareddrives/detectree2/data/" + "Paracou"
img_path = site_path + "/rgb/2016/Paracou_RGB_2016_10cm.tif"
lidar = "/content/drive/Shareddrives/detectree2/data/Paracou/lidar/Par_2016_CHM_g10_sub0.2_1m.tif"

test_folder = site_path + tiles + suffix + "/test"
pred_folder = test_folder + "/predictions"
shutil.rmtree(site_path + tiles + suffix + "/test/" + "predictions", True)
print(date + "_" + name + "/model_" + model_num + ".pth")
# Out:
# 221026_Paracou2016/model_32.pth

# %%
suffix = "30_30_0.4"
name = "Paracou2016" + "Danum" + "SepilokE" + "SepilokW"
tiles = "/tiles2016_"
date = "221026"
model_num = "22"


trained_model = dir + "/models/" + date + "_" + name + "/model_" + model_num + ".pth"

site_path = "/content/drive/Shareddrives/detectree2/data/" + "Paracou"
img_path = site_path + "/rgb/2016/Paracou_RGB_2016_10cm.tif"
lidar = "/content/drive/Shareddrives/detectree2/data/Paracou/lidar/Par_2016_CHM_g10_sub0.2_1m.tif"

test_folder = site_path + tiles + suffix + "/test"
pred_folder = test_folder + "/predictions"
shutil.rmtree(site_path + tiles + suffix + "/test/" + "predictions", True)
print(date + "_" + name + "/model_" + model_num + ".pth")
# Out:
# 221026_Paracou2016DanumSepilokESepilokW/model_22.pth

# %%
suffix = "30_30_0.4"
name = "Paracou2016"
tiles = "/tiles2016_"
date = "221027combined"
model_num = "18"


#trained_model = "/content/drive/Shareddrives/detectree2/models/220723_withParacouUAV.pth"
trained_model = dir + "/models/" + date + "_" + name + "/model_" + model_num + ".pth"
#trained_model = "/content/drive/Shareddrives/ForestRegen_summer2022/data/tilesTEST/model_no_tuning/train_outputs_palms/Model_10.pth"

site_path = "/content/drive/Shareddrives/detectree2/data/" + "Paracou"
img_path = site_path + "/rgb/2016/Paracou_RGB_2016_10cm.tif"
lidar = "/content/drive/Shareddrives/detectree2/data/Paracou/lidar/Par_2016_CHM_g10_sub0.2_1m.tif"

test_folder = site_path + tiles + suffix + "/test"
pred_folder = test_folder + "/predictions"
shutil.rmtree(site_path + tiles + suffix + "/test/" + "predictions", True)
print(date + "_" + name + "/model_" + model_num + ".pth")
# Out:
# 221027combined_Paracou2016/model_18.pth

# %% [markdown]
# ### For Danum

# %% [markdown]
# Single

# %%
suffix = "30_30_0.4"
name = "Danum"
tiles = "/tiles_"
date = "221026"
model_num = "33"


#trained_model = "/content/drive/Shareddrives/detectree2/models/220723_withParacouUAV.pth"
#trained_model = dir +  "/models/" + date + "_" + name + "/model_" + model_num + ".pth"
#trained_model = "/content/drive/Shareddrives/ForestRegen_summer2022/data/tilesTEST/model_no_tuning/train_outputs_palms/Model_10.pth"

site_path = "/content/drive/Shareddrives/detectree2/data/" + name
img_path = "/content/drive/Shareddrives/detectree2/data/Danum/rgb/Dan_2014_RGB_project_to_CHM.tif"
lidar = "/content/drive/Shareddrives/detectree2/data/Danum/lidar/Danum_2014_CHM_g10_sub0.2_1m.tif"

test_folder = site_path + tiles + suffix + "/test"
pred_folder = test_folder + "/predictions"
shutil.rmtree(site_path + "/tiles_" + suffix + "/test/" + "predictions", True)
print(date + "_" + name + "/model_" + model_num + ".pth")
# Out:
# 221026_Danum/model_33.pth

# %% [markdown]
# Combined

# %%
suffix = "30_30_0.4"
name = "Paracou2016" + "Danum" + "SepilokE" + "SepilokW"
tiles = "/tiles_"
date = "221026"
model_num = "22"


trained_model = dir + "/models/" + date + "_" + name + "/model_" + model_num + ".pth"
#trained_model = "/content/drive/Shareddrives/ForestRegen_summer2022/data/tilesTEST/model_no_tuning/train_outputs_palms/Model_10.pth"

site_path = "/content/drive/Shareddrives/detectree2/data/" + "Danum"
img_path = "/content/drive/Shareddrives/detectree2/data/Danum/rgb/Dan_2014_RGB_project_to_CHM.tif"
lidar = "/content/drive/Shareddrives/detectree2/data/Danum/lidar/Danum_2014_CHM_g10_sub0.2_1m.tif"

test_folder = site_path + tiles + suffix + "/test"
pred_folder = test_folder + "/predictions"
shutil.rmtree(site_path + tiles + suffix + "/test/" + "predictions", True)
print(date + "_" + name + "/model_" + model_num + ".pth")
# Out:
# 221026_Paracou2016DanumSepilokESepilokW/model_22.pth

# %% [markdown]
# Combined -> single

# %%
suffix = "30_30_0.4"
name = "Danum"
tiles = "/tiles_"
date = "221027combined"
model_num = "9"


#trained_model = "/content/drive/Shareddrives/detectree2/models/220723_withParacouUAV.pth"
trained_model = dir + "/models/" + date + "_" + name + "/model_" + model_num + ".pth"
#trained_model = "/content/drive/Shareddrives/ForestRegen_summer2022/data/tilesTEST/model_no_tuning/train_outputs_palms/Model_10.pth"

site_path = "/content/drive/Shareddrives/detectree2/data/" + name
img_path = "/content/drive/Shareddrives/detectree2/data/Danum/rgb/Dan_2014_RGB_project_to_CHM.tif"
lidar = "/content/drive/Shareddrives/detectree2/data/Danum/lidar/Danum_2014_CHM_g10_sub0.2_1m.tif"

test_folder = site_path + tiles + suffix + "/test"
pred_folder = test_folder + "/predictions"
shutil.rmtree(site_path + tiles + suffix + "/test/" + "predictions", True)
print(date + "_" + name + "/model_" + model_num + ".pth")
# Out:
# 221027combined_Danum/model_9.pth

# %% [markdown]
# ### For Sepilok East

# %% [markdown]
# Single

# %%
suffix = "30_30_0.4"
name = "Sepilok"
tiles = "/tilesE_"
date = "221026"
model_num = "23"


#trained_model = "/content/drive/Shareddrives/detectree2/models/220723_withParacouUAV.pth"
#trained_model = dir +  "/models/" + date + "_" + name + "E" + "/model_" + model_num + ".pth"
#trained_model = "/content/drive/Shareddrives/ForestRegen_summer2022/data/tilesTEST/model_no_tuning/train_outputs_palms/Model_10.pth"

site_path = "/content/drive/Shareddrives/detectree2/data/" + name
img_path = "/content/drive/Shareddrives/detectree2/data/Sepilok/rgb/RCD105_MA14_21_orthomosaic_20141023_reprojected_full_res.tif"
lidar = "/content/drive/Shareddrives/detectree2/data/Sepilok/lidar/Sep_2014_coarse_CHM_g10_sub0.01_0.5m.tif"

test_folder = site_path + tiles + suffix + "/test"
pred_folder = test_folder + "/predictions"
shutil.rmtree(site_path + tiles + suffix + "/test/" + "predictions", True)
print(date + "_" + name + "/model_" + model_num + ".pth")
# Out:
# 221026_Sepilok/model_23.pth

# %% [markdown]
# Combined

# %%
suffix = "30_30_0.4"
name = "Paracou2016" + "Danum" + "SepilokE" + "SepilokW"
tiles = "/tilesE_"
date = "221026"
model_num = "22"


trained_model = dir + "/models/" + date + "_" + name + "/model_" + model_num + ".pth"
#trained_model = "/content/drive/Shareddrives/ForestRegen_summer2022/data/tilesTEST/model_no_tuning/train_outputs_palms/Model_10.pth"

site_path = "/content/drive/Shareddrives/detectree2/data/" + "Sepilok"
img_path = "/content/drive/Shareddrives/detectree2/data/Sepilok/rgb/RCD105_MA14_21_orthomosaic_20141023_reprojected_full_res.tif"
lidar = "/content/drive/Shareddrives/detectree2/data/Sepilok/lidar/Sep_2014_coarse_CHM_g10_sub0.01_0.5m.tif"

test_folder = site_path + tiles + suffix + "/test"
pred_folder = test_folder + "/predictions"
shutil.rmtree(site_path + tiles + suffix + "/test/" + "predictions", True)
print(date + "_" + name + "/model_" + model_num + ".pth")
# Out:
# 221026_Paracou2016DanumSepilokESepilokW/model_22.pth

# %% [markdown]
# Combined -> single

# %%
suffix = "30_30_0.4"
name = "SepilokE"
tiles = "/tilesE_"
date = "221027combined"
model_num = "10"


trained_model = dir + "/models/" + date + "_" + name + "/model_" + model_num + ".pth"

site_path = "/content/drive/Shareddrives/detectree2/data/" + "Sepilok"
img_path = "/content/drive/Shareddrives/detectree2/data/Sepilok/rgb/RCD105_MA14_21_orthomosaic_20141023_reprojected_full_res.tif"
lidar = "/content/drive/Shareddrives/detectree2/data/Sepilok/lidar/Sep_2014_coarse_CHM_g10_sub0.01_0.5m.tif"

test_folder = site_path + tiles + suffix + "/test"
pred_folder = test_folder + "/predictions"
shutil.rmtree(site_path + tiles + suffix + "/test/" + "predictions", True)
print(date + "_" + name + "/model_" + model_num + ".pth")
# Out:
# 221027combined_SepilokE/model_10.pth

# %% [markdown]
# ### For Sepilok West

# %%
suffix = "30_30_0.4"
name = "Sepilok"
tiles = "/tilesW_"
date = "221026"
model_num = "16"


#trained_model = "/content/drive/Shareddrives/detectree2/models/220723_withParacouUAV.pth"
trained_model = dir +  "/models/" + date + "_" + name + "W" + "/model_" + model_num + ".pth"
#trained_model = "/content/drive/Shareddrives/ForestRegen_summer2022/data/tilesTEST/model_no_tuning/train_outputs_palms/Model_10.pth"

site_path = "/content/drive/Shareddrives/detectree2/data/" + name
img_path = "/content/drive/Shareddrives/detectree2/data/Sepilok/rgb/RCD105_MA14_21_orthomosaic_20141023_reprojected_full_res.tif"
lidar = "/content/drive/Shareddrives/detectree2/data/Sepilok/lidar/Sep_2014_coarse_CHM_g10_sub0.01_0.5m.tif"

test_folder = site_path + tiles + suffix + "/test"
pred_folder = test_folder + "/predictions"
shutil.rmtree(site_path + "/tilesW_" + suffix + "/test/" + "predictions", True)
print(date + "_" + name + "W/model_" + model_num + ".pth")
# Out:
# 221026_SepilokW/model_16.pth

# %%
suffix = "30_30_0.4"
name = "Paracou2016" + "Danum" + "SepilokE" + "SepilokW"
tiles = "/tilesW_"
date = "221026"
model_num = "22"


trained_model = dir + "/models/" + date + "_" + name + "/model_" + model_num + ".pth"
#trained_model = "/content/drive/Shareddrives/ForestRegen_summer2022/data/tilesTEST/model_no_tuning/train_outputs_palms/Model_10.pth"

site_path = "/content/drive/Shareddrives/detectree2/data/" + "Sepilok"
img_path = "/content/drive/Shareddrives/detectree2/data/Sepilok/rgb/RCD105_MA14_21_orthomosaic_20141023_reprojected_full_res.tif"
lidar = "/content/drive/Shareddrives/detectree2/data/Sepilok/lidar/Sep_2014_coarse_CHM_g10_sub0.01_0.5m.tif"

test_folder = site_path + tiles + suffix + "/test"
pred_folder = test_folder + "/predictions"
shutil.rmtree(site_path + tiles + suffix + "/test/" + "predictions", True)
print(date + "_" + name + "/model_" + model_num + ".pth")
# Out:
# 221026_Paracou2016DanumSepilokESepilokW/model_22.pth

# %%
suffix = "30_30_0.4"
name = "SepilokW"
tiles = "/tilesW_"
date = "221027combined"
model_num = "11"


trained_model = dir + "/models/" + date + "_" + name + "/model_" + model_num + ".pth"

site_path = "/content/drive/Shareddrives/detectree2/data/" + "Sepilok"
img_path = "/content/drive/Shareddrives/detectree2/data/Sepilok/rgb/RCD105_MA14_21_orthomosaic_20141023_reprojected_full_res.tif"
lidar = "/content/drive/Shareddrives/detectree2/data/Sepilok/lidar/Sep_2014_coarse_CHM_g10_sub0.01_0.5m.tif"

test_folder = site_path + tiles + suffix + "/test"
pred_folder = test_folder + "/predictions"
shutil.rmtree(site_path + tiles + suffix + "/test/" + "predictions", True)
print(date + "_" + name + "/model_" + model_num + ".pth")
# Out:
# 221027combined_SepilokW/model_11.pth

# %% [markdown]
# # Make predictions

# %% [markdown]
# ### Predict

# %% [markdown]
# Predict and transform outputs
#
# Resizing in training seems to make a big difference to the predictions. Make sure the tiles are resized in a consistent way to training.

# %%
import rasterio
from detectree2.models.outputs import project_to_geojson

# set up config
cfg = setup_cfg(update_model=trained_model)
#cfg.INPUT.MIN_SIZE_TEST = 1000
#cfg.INPUT.MAX_SIZE_TEST = 1100
#cfg.TEST.DETECTIONS_PER_IMAGE = 100

predictions_on_data(site_path + tiles + suffix, DefaultPredictor(cfg))
#clean_predictions(pred_folder, 0.8)
to_eval_geojson(pred_folder)

# Read in the tiff file
data = rasterio.open(img_path)
project_to_geojson(data, pred_folder + "/", pred_folder + "/")
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %% [markdown]
# ## Visualise test data

# %%
from detectron2.utils.visualizer import Visualizer
from detectree2.models.train import combine_dicts, get_tree_dicts
from detectron2.data import DatasetCatalog, MetadataCatalog
import cv2
from PIL import Image

#name = "Paracou2016"
dataset_dicts = get_tree_dicts(test_folder)
#trees_metadata = MetadataCatalog.get(name + "_train")
#dataset_dicts = get_tree_dicts("./")
for d in dataset_dicts:
    img = cv2.imread(d["file_name"])
    print(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], scale=0.7)
    out = visualizer.draw_dataset_dict(d)
    image = cv2.cvtColor(out.get_image()[:, :, ::-1], cv2.COLOR_BGR2RGB)
    display(Image.fromarray(image))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Assess accuracy of predictions

# %% [markdown]
# First across all heights

# %%
from detectree2.models.evaluation import site_f1_score2

#print(test_folder)
#print(pred_folder)
prec, recall, f1 = site_f1_score2(
    site_path + tiles + suffix , test_directory=test_folder,
    pred_directory = pred_folder , 
    IoU_threshold=0.5, border_filter=[False, 1], conf_threshold=0.3,
    area_threshold=16)
# Out:
# RCD105_MA14_21_orthomosaic_20141023_reprojected_full_res_606843_647667_30_30_32650.geojson
# tps: 39
# fps: 15
# fns: 20
#
# RCD105_MA14_21_orthomosaic_20141023_reprojected_full_res_607083_647367_30_30_32650.geojson
# tps: 18
# fps: 34
# fns: 23
#
# RCD105_MA14_21_orthomosaic_20141023_reprojected_full_res_606933_647667_30_30_32650.geojson
# tps: 30
# fps: 22
# fns: 37
#
# Precision   Recall   F1
# 0.5506329113924051 0.5209580838323353 0.5353846153846155
#
# Total_trees= 167
# med_height= 0

# %% [markdown]
# Then by height bins

# %%
prec, recall, f1 = site_f1_score2(site_path + tiles + suffix , test_directory=test_folder ,
                                  pred_directory = pred_folder , 
                                  IoU_threshold=0.5, border_filter=[False, 3], conf_threshold=0.4,
                                  area_threshold=16,
                                  lidar_img = lidar,
                                  min_height = 35,
                                  max_height = 200)
# Out:
# Paracou_RGB_2016_10cm_286612_583771_30_30_2972.geojson
# tps: 3
# fps: 2
# fns: 0
#
# Paracou_RGB_2016_10cm_286762_583891_30_30_2972.geojson
# tps: 9
# fps: 3
# fns: 4
#
# Paracou_RGB_2016_10cm_286792_583771_30_30_2972.geojson
# tps: 5
# fps: 2
# fns: 1
#
# Paracou_RGB_2016_10cm_287302_584071_30_30_2972.geojson
# tps: 13
# fps: 9
# fns: 4
#
# Paracou_RGB_2016_10cm_286612_583021_30_30_2972.geojson
# tps: 6
# fps: 4
# fns: 2
#
# Paracou_RGB_2016_10cm_286162_581251_30_30_2972.geojson
# tps: 6
# fps: 2
# fns: 3
#
# Paracou_RGB_2016_10cm_286012_582631_30_30_2972.geojson
# tps: 9
# fps: 3
# fns: 2
#
# Paracou_RGB_2016_10cm_286132_582691_30_30_2972.geojson
# tps: 4
# fps: 1
# fns: 1
#
# Precision   Recall   F1
# 0.6790123456790124 0.7638888888888888 0.7189542483660132
#
# Total_trees= 72
# med_height= 37.07500076293945

# %% [markdown]
# Evaluate based on height

# %% [markdown]
# ## Using in built evaluator

# %%
#import the COCO Evaluator to use the COCO Metrics
from detectron2.config import get_cfg
from detectron2.engine import DefaultPredictor
from detectron2.data import build_detection_test_loader
from detectron2.data.datasets import register_coco_instances
from detectron2.evaluation import COCOEvaluator, inference_on_dataset

#register your data
#register_coco_instances("my_dataset_train", {}, "/code/detectron2/detectron2/instances_train2017.json", "/code/detectron2/detectron2/train2017")
#register_coco_instances("my_dataset_val", {}, "/code/detectron2/detectron2/instances_val2017.json", "/code/detectron2/detectron2/val2017")
#register_coco_instances("my_dataset_test", {}, "/code/detectron2/detectron2/instances_test2017.json", "/code/detectron2/detectron2/test2017")
register_test_data(test_folder)

#load the config file, configure the threshold value, load weights 
#cfg = get_cfg()
#cfg.merge_from_file("/code/detectron2/detectron2/output/custom_mask_rcnn_X_101_32x8d_FPN_3x_Iteration_3_dataset.yaml")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.3  # set threshold for this model
#cfg.MODEL.WEIGHTS = "/code/detectron2/detectron2/output/model_final.pth"

# Create predictor
predictor = DefaultPredictor(cfg)

#Call the COCO Evaluator function and pass the Validation Dataset
evaluator = COCOEvaluator("tree_test", cfg, False, output_dir="./output/")
val_loader = build_detection_test_loader(cfg, "tree_test")

#Use the created predicted model in the previous step
inference_on_dataset(predictor.model, val_loader, evaluator)
# Out:
# WARNING:detectron2.evaluation.coco_evaluation:COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.106
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.240
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.073
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.247
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.010
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.068
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.167
# ...
